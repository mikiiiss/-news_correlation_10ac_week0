# %% [markdown]
# <a href="https://colab.research.google.com/github/mikiiiss/-news_correlation_10ac_week0/blob/main/task2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
path="/content/drive/MyDrive/data set/data.csv.zip"
df= pd.read_csv(path)
df.head(50)
# Out:
#     article_id           source_id                   source_name  \
# 0        81664                 NaN                        Forbes
# 1        81667                 NaN                           CNA
# 2        81694                time                          Time
# 3        81695                 NaN                      Phys.Org
# 4        81703                 NaN                Digital Trends
# 5        81707  al-jazeera-english            Al Jazeera English
# 6        81717            bbc-news                      BBC News
# 7        81719                 NaN                      Phys.Org
# 8        81723                 NaN                      Deadline
# 9        81727                 NaN                      Euronews
# 10       81731                 NaN                      Phys.Org
# 11       81739                  rt                            RT
# 12       81741                 NaN                      Phys.Org
# 13       81751                 NaN                        Forbes
# 14       81752                 NaN                        Forbes
# 15       81878                 NaN                     The Punch
# 16       81755  al-jazeera-english            Al Jazeera English
# 17       81761                 NaN                      Euronews
# 18       81779                 NaN                           CNA
# 19       81787                 NaN                        Forbes
# 20       81809                 NaN                           CNA
# 21       81811                 NaN  International Business Times
# 22       81815                 NaN            The Indian Express
# 23       81829                 NaN                        Forbes
# 24       81836                 NaN                        Forbes
# 25       81841                 NaN                ETF Daily News
# 26       81842            bbc-news                      BBC News
# 27       81853            abc-news                      ABC News
# 28       81860                 NaN            Globalsecurity.org
# 29       81862                 NaN            Marketscreener.com
# 30       81864                 NaN            Marketscreener.com
# 31       81870                 NaN                        Forbes
# 32       81884                 NaN                           CNA
# 33       81917                 NaN                      Phys.Org
# 34       81924                 NaN                     The Punch
# 35       81936                 NaN            Marketscreener.com
# 36       81937                 NaN            Marketscreener.com
# 37       81938  the-times-of-india            The Times of India
# 38       81954                 NaN                 GlobeNewswire
# 39       81976                 NaN            Marketscreener.com
# 40       82108  al-jazeera-english            Al Jazeera English
# 41       81977                 NaN                ETF Daily News
# 42       81981                 NaN            Marketscreener.com
# 43       81984                 NaN            Marketscreener.com
# 44       82025                 NaN            Marketscreener.com
# 45       82059                 NaN            Marketscreener.com
# 46       82062                 NaN            Marketscreener.com
# 47       82069  the-times-of-india            The Times of India
# 48       82078                  rt                            RT
# 49       82097  al-jazeera-english            Al Jazeera English
#
#                                                author  \
# 0   Elizabeth Brownfield, Contributor, \n Elizabet...
# 1                                                 NaN
# 2                               Christina Larson / AP
# 3                                        Sara Schmidt
# 4                                        Jason Struss
# 5                                          Al Jazeera
# 6                    https://www.facebook.com/bbcnews
# 7                                    Carlyn Chatfield
# 8                                       Patrick Hipes
# 9                                                 NaN
# 10        Louw Claassens, David Harasti, Graham Short
# 11                                                 RT
# 12                                  Sarah-Sophie Weil
# 13  Sarah Ferguson, UNICEF USA, \n Sarah Ferguson,...
# 14  Dan Lambe, Forbes Councils Member, \n Dan Lamb...
# 15                                         Tope Alabi
# 16                                         Al Jazeera
# 17                                                NaN
# 18                                                NaN
# 19  Patty Lee, Contributor, \n Patty Lee, Contribu...
# 20                                                NaN
# 21                                     Imran Marashli
# 22                                         Mira Patel
# 23  Aly Walansky, Contributor, \n Aly Walansky, Co...
# 24  Dipka Bhambhani, Senior Contributor, \n Dipka ...
# 25                                    MarketBeat News
# 26                   https://www.facebook.com/bbcnews
# 27                 CHRISTINA LARSON AP science writer
# 28                                          John Pike
# 29                                                NaN
# 30                                                NaN
# 31  Jennifer Ferrise, Forbes Staff, \n Jennifer Fe...
# 32                                                NaN
# 33                                          Science X
# 34                                         Gift Habib
# 35                                                NaN
# 36                                                NaN
# 37                                       Malathy Iyer
# 38                               Research and Markets
# 39                                                NaN
# 40                                         Al Jazeera
# 41                                    MarketBeat News
# 42                                                NaN
# 43                                                NaN
# 44                                                NaN
# 45                                                NaN
# 46                                                NaN
# 47                                                PTI
# 48                                                 RT
# 49                                      Hamza Mohamed
#
#                                                 title  \
# 0   superstar chef yannick alléno brings refined f...
# 1   nice claim top spot in ligue 1 with late win a...
# 2   amphibians are the world’s most vulnerable spe...
# 3               image: rusty red waters in madagascar
# 4   everything leaving max (formerly hbo max) in n...
# 5   unga calls for humanitarian truce in israel-ha...
# 6   malawi heatwave warning issued as temperatures...
# 7   researcher scans tropical forest with mixed-re...
# 8   ‘taylor swift: the eras tour’ movie: tickets, ...
# 9   marine le pen found guilty of defamation after...
# 10  tiny and mysterious: research sheds light on s...
# 11  russian marine scientists to conduct african r...
# 12  how animal traits have shaped the journey of s...
# 13               investing in girls and their futures
# 14  setting intentional climate solution goals as ...
# 15  full list: davido, rema win big at 2023 trace ...
# 16  ‘kids whose insides are destroyed’: the return...
# 17  red alert for the ev market: china puts curb o...
# 18  south star eyes faster ramp up of brazil graph...
# 19  10 of the best matcha powders that are smooth ...
# 20  miners race to realise graphite projects as ch...
# 21  climate change primary driver of amphibian dec...
# 22  the bloody history behind how israel, and pale...
# 23  20 delicious dishes to enjoy while celebrating...
# 24  turquoise hydrogen producers could capture flo...
# 25    tirupati graphite (lon:tgr) trading 3.9% higher
# 26       mother pleads for help over missing daughter
# 27  amphibians are the world's most vulnerable spe...
# 28  malawi begins free food distribution to hunger...
# 29  tirupati graphite says interim performance "si...
# 30         lion sees path to restarting graphite mine
# 31  the best places to buy christmas cards online ...
# 32  amphibian crisis: 41% of species deemed threat...
# 33  bouldering in south-central madagascar: a new ...
# 34  rule of law: nigeria ranks 120th out of 142 co...
# 35  tirupati says china graphite export curbs "pos...
# 36  base resources limited - notice of 2023 annual...
# 37  mumbai doctors remove spine tumour 30 times si...
# 38  global cobalt industry report 2023-2028: asia ...
# 39  miners race to realise graphite projects as ch...
# 40  israel tells citizens to leave egypt, jordan ‘...
# 41  vox royalty corp. (nasdaq:voxr) sees large gro...
# 42  base resources limited - ltip performance righ...
# 43  orange : accelerates the deployment of orange ...
# 44  base resources limited - quarterly activities ...
# 45  african apparel industry's future hangs on a u...
# 46  base resources limited - kwale operations to c...
# 47  countries should build trust on maritime front...
# 48   african governments discuss root causes of coups
# 49  ‘music to beijing’s ears’: has china won the m...
#
#                                           description  \
# 0   Now open in Mayfair at Four Seasons Hotel Lond...
# 1   Nice moved into provisional first place in the...
# 2   The world’s frogs, salamanders, newts, and oth...
# 3   Iron-rich sediment colors the red-orange water...
# 4   From Gangs of London to Fear the Walking Dead ...
# 5   The resolution passed with 120 votes in favour...
# 6   Temperatures could soar to 44C, the weather bu...
# 7   Rice University scientists used a commercially...
# 8   Taylor Swift has the highest-grossing concert ...
# 9   Marine Le Pen was convicted of defamation agai...
# 10  Seahorses are considered fabled creatures by m...
# 11  Russian scientists from VNIRO will conduct res...
# 12  The devastating tsunami that hit Japan in Marc...
# 13  Investing in girls is not only the right thing...
# 14  A growing number of companies are using a seem...
# 15  Nigerian artistes Davido and Rema won big at t...
# 16  Mauritius grapples with a drug epidemic of unp...
# 17  China is the world's top graphite producer and...
# 18  RIO DE JANEIRO :South Star Battery Metals is l...
# 19  Depending on how you plan to use it and what y...
# 20  As China moved to control some exports of key ...
# 21  Climate change has become the main factor driv...
# 22  The Israel-Palestine conflict, a century-old s...
# 23  It's a perfect time to show our favorite pasta...
# 24  Turquoise hydrogen from natural gas produces a...
# 25  Shares of Tirupati Graphite plc (LON:TGR – Get...
# 26  A number of Israeli civilians and soldiers are...
# 27  The world’s frogs, salamanders, newts and othe...
# 28  Malawi has started distributing free corn and ...
# 29  (marketscreener.com) Tirupati Graphite PLC on ...
# 30  (marketscreener.com) Vancouver, British Columb...
# 31  'Tis the season for snail mail! The best place...
# 32  WASHINGTON: Earth's amphibians - from the thor...
# 33  Named after its habitat preference, Paroedura ...
# 34  Nigeria is ranked 120th out of 142 countries i...
# 35  (marketscreener.com) Tirupati Graphite PLC sha...
# 36  (marketscreener.com) \n\n   AIM and Media Rele...
# 37  The patient, Tafita Fanambinantsoa Andriatsara...
# 38  Dublin, Oct. 13, 2023 (GLOBE NEWSWIRE) -- The ...
# 39  (marketscreener.com) As China moved to control...
# 40  National Security Council raises threat levels...
# 41  Vox Royalty Corp. (NASDAQ:VOXR – Get Free Repo...
# 42  (marketscreener.com) \n\n   AIM and Media Rele...
# 43  (marketscreener.com) \n \n A committed multi-s...
# 44  (marketscreener.com) \n\n   AIM and Media Rele...
# 45  (marketscreener.com) Norah Nasimiyu knows the\...
# 46  (marketscreener.com) \n\n   AIM and Media Rele...
# 47  "How do we build trust? We build trust through...
# 48  African government representatives met in Togo...
# 49  Mohamed Muizzu's election win is a setback for...
#
#                                                   url  \
# 0   https://www.forbes.com/sites/elizabethbrownfie...
# 1   https://www.channelnewsasia.com/sport/nice-cla...
# 2   https://time.com/6320467/amphibians-most-vulne...
# 3   https://phys.org/news/2023-10-image-rusty-red-...
# 4   https://www.digitaltrends.com/movies/everythin...
# 5   https://www.aljazeera.com/news/2023/10/27/unga...
# 6    https://www.bbc.co.uk/news/world-africa-67086254
# 7   https://phys.org/news/2023-10-scans-tropical-f...
# 8   https://deadline.com/feature/taylor-swift-eras...
# 9   https://www.euronews.com/2023/10/13/marine-le-...
# 33  Named after its habitat preference, Paroedura ...  Madagascar
# 34  Nigeria is ranked 120th out of 142 countries i...  Madagascar
# 35  (Alliance News) - Tirupati Graphite PLC shares...  Madagascar
# 36  AIM and Media Release  \n24 October 2023\nBase...  Madagascar
# 37  AI imagines Durga Maa's 9 forms that are worsh...  Madagascar
# 38  Dublin, Oct. 13, 2023 (GLOBE NEWSWIRE) -- The ...  Madagascar
# 39  Oct 20 (Reuters) - As China moved to control s...  Madagascar
# 40  Israel has called on its citizens to immediate...    Maldives
# 41  Vox Royalty Corp. (NASDAQ:VOXR – Get Free Repo...  Madagascar
# 42  AIM and Media Release  \n13 October 2023\nBase...  Madagascar
# 43  A committed multi-service operator, Orange has...  Madagascar
# 44  AIM and Media Release  \n31 October 2023\nBase...  Madagascar
# 45  * AGOA duty free trade programme expires in 20...  Madagascar
# 46  AIM and Media Release  \n30 October 2023\nBase...  Madagascar
# 47  Defence Minister Rajnath Singh on Monday stres...  Madagascar
# 48  The first Lome Peace and Security Forum (LPSF)...        Mali
# 49  The Maldives has a population of half a millio...    Maldives
#
#                                               article title_sentiment
# 0   pavyllon london, at four seasons hotel london ...         Neutral
# 1   nice moved into provisional first place in the...        Positive
# 2   the world’s frogs, salamanders, newts and othe...        Negative
# 3   iron-rich sediment colors the red-orange water...         Neutral
# 4   everything ends. no, i’m not having an existen...         Neutral
# 5   the resolution passed with 120 votes in favour...         Neutral
# 6   malawians have been warned of an extreme heatw...         Neutral
# 7   rice university scientists used a commercially...         Neutral
# 8   taylor swifthas the highest-grossing concert t...         Neutral
# 9   marine le pen, former leader of france's far-r...        Negative
# 10  seahorses are consideredfabled creaturesby man...         Neutral
# 11  scientists from the all-russian research insti...         Neutral
# 12  the devastatingtsunamithat hit japan in march ...         Neutral
# 13  in october 2023, unicef education officer beno...         Neutral
# 14  dan lambe is the ceo of the arbor day foundati...         Neutral
# 15  nigerian artistes davido and rema won big at t...        Positive
# 16  the island nation is grappling with a drug epi...        Negative
# 17  china will bring in requirements for export pe...         Neutral
# 18  rio de janeiro: south star battery metals is l...         Neutral
# 19  matcha has made its way to nearly every coffee...        Positive
# 20  as china moved to control some exports of key ...         Neutral
# 21  climate change has become the main factor driv...        Negative
# 22  the conflict between israel and palestine bega...        Negative
# 23  there’s so many ways to enjoy pasta. some may ...        Positive
# 24  while much of the limelight is on blue or gree...        Positive
# 25  shares of tirupati graphite plc (lon:tgr–get f...        Positive
# 26  a german mother is pleading for information ab...         Neutral
# 27  the world’s frogs, salamanders, newts and othe...        Negative
# 28  by  lameck masina october 10, 2023 malawi has ...         Neutral
# 29  (alliance news) - tirupati graphite plc on thu...        Positive
# 30  vancouver, british columbia, oct.  31, 2023  (...         Neutral
# 31  in this digital age that’s a constant swirl of...        Positive
# 32  washington: earth's amphibians - from the thor...        Negative
# 33  named after its habitat preference, paroedura ...         Neutral
# 34  nigeria is ranked 120th out of 142 countries i...         Neutral
# 35  (alliance news) - tirupati graphite plc shares...         Neutral
# 36     aim and media release 24 october 2023  base...         Neutral
# 37  mumbai: can a surgery span over a five-day per...         Neutral
# 38  dublin, oct.  13, 2023  (globe newswire) -- th...         Neutral
# 39  oct 20 (reuters) - as china moved to control s...         Neutral
# 40  national security council raises threat levels...         Neutral
# 41  vox royalty corp. (nasdaq:voxr–get free report...        Positive
# 42     aim and media release 13 october 2023  base...         Neutral
# 43  a committed multi-service operator, orange has...         Neutral
# 44     aim and media release 31 october 2023  base...         Neutral
# 45  * agoa duty free trade programme expires in 20...         Neutral
# 46     aim and media release 30 october 2023  base...         Neutral
# 47  pti defence minister  rajnath singh  on monday...         Neutral
# 48  the first lome peace and security forum (lpsf)...         Neutral
# 49  mohamed muizzu’s election win is a setback for...         Neutral

# %%
df['category'].unique()
# Out:
# array(['Monaco', 'Madagascar', 'Mexico', 'Maldives', 'Mali', 'Barbados',
#        'Nicaragua', 'Congo, The Democratic Republic of the',
#        'North Macedonia', 'Malta', 'Poland', 'Myanmar',
#        'Russian Federation', 'Mongolia', 'Montenegro', 'Malaysia',
#        'Romania', 'Mozambique', 'Montserrat', 'South Sudan', 'News',
#        'Israel', 'Mauritania', 'Mauritius', 'Netherlands', 'Martinique',
#        'Malawi', 'Germany', 'Niger', 'Namibia', 'Nigeria', 'Georgia',
#        'Nepal', 'Facebook', 'Norway', 'COVID', 'Peru', 'Travel',
#        'History', 'Papua New Guinea', 'New Zealand', 'Sports', 'Oman',
#        'Pakistan', 'Panama', 'Love', 'America', 'Philippines', 'Palau',
#        'Politics', 'Armenia', 'Food', 'Sudan', 'Puerto Rico', 'Weather',
#        'Real estate', 'Cars', 'Senegal', 'Singapore', 'Stock', 'Ghana',
#        'TikTok', 'Photography', 'Kazakhstan', 'Games', 'Climate', 'Space',
#        'Somalia', 'Tonga', 'Architecture', 'Art', 'Africa',
#        'Relationships', 'Qatar', 'world', 'Beauty', 'Podcasts', 'Yoga',
#        'Coding', 'Cryptocurrency', 'Nutrition', 'Design',
#        'Sustainability', 'Blockchain', 'Startups',
#        'Artificial Intelligence', 'Motivation', 'Hiking', 'Productivity',
#        'Health', 'Philosophy', 'Europe', 'Serbia', 'Google', 'YouTube',
#        'Amazon', 'Jobs', 'Movies', 'Music', 'Technology', 'Sweden',
#        'Bitcoin', 'Finance', 'Fashion', 'Instagram', 'Fitness', 'Science',
#        'Education', 'Home', nan, 'Asia', 'Portugal', 'Paraguay', 'Pets',
#        'Palestine, State of', 'Rwanda', 'Saudi Arabia', 'Sierra Leone',
#        'El Salvador', 'San Marino', 'Suriname', 'Slovakia', 'Ukraine',
#        'Slovenia', 'Seychelles', 'Tunisia', 'United States', 'Turkey',
#        'Taiwan, Province of China', 'Uganda', 'Uruguay', 'Uzbekistan',
#        'Yemen', 'Samoa', 'Virgin Islands, U.S.', 'Viet Nam', 'Vanuatu',
#        'South Africa', 'Zambia', 'Zimbabwe', 'Thailand', 'Tajikistan',
#        'Chad', 'Turkmenistan', 'Recipes', 'Austria', 'DIY', 'Psychology',
#        'Virtual Reality', 'Australia', 'Meditation', 'Gardening', 'Vegan',
#        'Parenting', 'Anime', 'Mindfulness', 'Bangladesh', 'Djibouti',
#        'Entrepreneurship', 'Azerbaijan', 'Belarus', 'Lithuania', 'Poetry',
#        'Happiness', 'Canada', 'Minimalism', 'Astronomy', 'Guam',
#        'Afghanistan', 'Aruba', 'United Arab Emirates', 'Angola',
#        'Andorra', 'Albania', 'Hungary', 'Guernsey', 'Antarctica',
#        'Argentina', 'Switzerland', 'Haiti', 'Burundi', 'Belgium', 'China',
#        'Benin', 'Iraq', 'Burkina Faso', 'Latvia', 'Bulgaria', 'Bahrain',
#        'Bahamas', 'Bosnia and Herzegovina', 'Botswana', 'Belize',
#        'Brazil', 'Bermuda', 'Central African Republic', 'Cyprus',
#        'Bhutan', 'Chile', "Côte d'Ivoire", 'Cameroon', 'Congo',
#        'Colombia', 'Christmas Island', 'Cabo Verde', 'Costa Rica', 'Cuba',
#        'Cayman Islands', 'Denmark', 'Egypt', 'Dominican Republic',
#        'Kenya', 'Algeria', 'Eritrea', 'Ecuador', 'Iceland', 'Spain',
#        'Estonia', 'Ethiopia', 'Finland', 'Fiji', 'France', 'Gabon',
#        'Cambodia', 'Libya', 'United Kingdom', 'Gibraltar', 'Guinea',
#        'Gambia', 'Greece', 'Iran, Islamic Republic of', 'Guatemala',
#        'Greenland', 'India', 'Guyana', 'Hong Kong', 'Luxembourg',
#        'Honduras', 'Croatia', 'Indonesia', 'Isle of Man', 'Ireland',
#        'Jersey', 'Italy', 'Jamaica', 'Jordan', 'Kyrgyzstan', 'Japan',
#        'Korea, Republic of', 'Lebanon', 'Kuwait', 'Liberia',
#        'Liechtenstein', 'Sri Lanka', 'Morocco', 'Macao', 'Réunion'],
#       dtype=object)

# %%
country_to_region = {
    'Africa': ['Madagascar','Mali','South Sudan','Morocco'],
    'US': ['United States', 'USA'],
    'China': ['China'],
    'EU': ['European Union', 'Germany', 'France', 'UK'],
    'Russia': ['Russia'],
    'Ukraine': ['Ukraine'],
    'Middle East': ['Middle East', 'Saudi Arabia', 'Iran']
}
for region, countries in country_to_region.items():
    df[region] = df['content'].str.contains('|'.join(countries), case=False)
df
region_counts = df[list(country_to_region.keys())].sum()
region_counts
# Out:
# Africa          222
# US             1799
# China          1000
# EU             2637
# Russia         1312
# Ukraine         868
# Middle East    1035
# dtype: int64

# %%
pd.set_option('display.max.rows',200)

# %%
 countries_with_many_articles = df['category'].value_counts().nsmallest(10)
 countries_with_many_articles
# Out:
# category
# Martinique    2
# Réunion       2
# Andorra       3
# Burundi       3
# Cabo Verde    3
# Honduras      3
# San Marino    4
# Gambia        4
# Minimalism    4
# Viet Nam      6
# Name: count, dtype: int64

# %%
  countries_with_many_articles = df['category'].value_counts().nlargest(10)
  countries_with_many_articles
# Out:
# category
# Stock          3687
# Canada         2066
# Health         2046
# Real estate    2030
# Technology     1993
# Finance        1850
# News           1401
# COVID          1345
# Education      1325
# Food           1144
# Name: count, dtype: int64

# %%
df[category].unique()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-12-512f4cb0f547> in <cell line: 1>()
# ----> 1 df[category].unique()
#
# NameError: name 'category' is not defined

# %%
country_to_region = {
    'Africa': ['Algeria', 'Angola', 'Benin', 'Botswana', 'Burkina Faso', 'Burundi', 'Cabo Verde',
               'Cameroon', 'Central African Republic', 'Chad', 'Comoros', 'Congo', 'Democratic Republic of the Congo',
               'Djibouti', 'Egypt', 'Equatorial Guinea', 'Eritrea', 'Eswatini', 'Ethiopia', 'Gabon', 'Gambia', 'Ghana',
               'Guinea', 'Guinea-Bissau', 'Ivory Coast', 'Kenya', 'Lesotho', 'Liberia', 'Libya', 'Madagascar', 'Malawi',
               'Mali', 'Mauritania', 'Mauritius', 'Morocco', 'Mozambique', 'Namibia', 'Niger', 'Nigeria', 'Rwanda',
               'Sao Tome and Principe', 'Senegal', 'Seychelles', 'Sierra Leone', 'Somalia', 'South Africa',
               'South Sudan', 'Sudan', 'Tanzania', 'Togo', 'Tunisia', 'Uganda', 'Zambia', 'Zimbabwe'],
    #'US': ['United States', 'USA'],
    #'China': ['China'],
    #'EU': ['North Macedonia', 'Malta', 'Poland', 'Montenegro', 'Germany', 'Netherlands', 'Romania', 'Georgia',
           'Norway', 'Ukraine', 'Czech Republic', 'Portugal', 'San Marino', 'Slovakia', 'Slovenia', 'Spain', 'Sweden',
           'Switzerland', 'United Kingdom', 'Iceland', 'Ireland', 'Italy', 'Albania', 'Andorra', 'Austria', 'Belarus',
           'Belgium', 'Bosnia and Herzegovina', 'Bulgaria', 'Croatia', 'Cyprus', 'Denmark', 'Estonia', 'Finland',
           'France', 'Greece', 'Hungary','Russia'],

    #'Ukraines': ['Ukraine'],
    #'Middle East': ['Middle East', 'Saudi Arabia', 'Iran']
}
for region, countries in country_to_region.items():
    df[region] = df['content'].str.contains('|'.join(countries), case=False)
    region_counts = df[list(country_to_region.keys())].sum()
    region_counts
# Out:
#   File "<ipython-input-23-8d01295a368f>", line 19
#     ],
#     ^
# SyntaxError: closing parenthesis ']' does not match opening parenthesis '{' on line 1

# %%
largest_websites = df['source_name'].value_counts().nlargest(10)
largest_websites
# Out:
# source_name
# ETF Daily News        16746
# The Times of India     7504
# GlobeNewswire          5423
# Globalsecurity.org     3119
# Forbes                 2784
# BBC News               2113
# ABC News               2058
# Business Insider       2034
# The Punch              1800
# Al Jazeera English     1664
# Name: count, dtype: int64

# %%
path="/content/drive/MyDrive/data set/traffic_data.zip"
df1=pd.read_csv(path)
df1.head(5)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-e964ff8460a4> in <cell line: 2>()
#       1 path="/content/drive/MyDrive/data set/traffic_data.zip"
# ----> 2 df1=pd.read_csv(path)
#       3 df1.head(5)
#
# NameError: name 'pd' is not defined

# %%
highest_traffic_websites = df1.nlargest(10, 'GlobalRank')
highest_traffic_websites
# Out:
#         GlobalRank  TldRank                  Domain  TLD  RefSubNets  RefIPs  \
# 999999     1000000   485328  toyotamusicfactory.com  com         222     280
# 999998      999999   485327          soderhomes.com  com         222     280
# 999997      999998   485326           pinkwater.com  com         222     280
# 999996      999997   485325             mt-lock.com  com         222     280
# 999995      999996   485324              kireie.com  com         222     280
# 999994      999995   485323         keith-baker.com  com         222     280
# 999993      999994   485322          irishcycle.com  com         222     280
# 999992      999993   485321                hmag.com  com         222     280
# 999991      999992   485320    exploring-africa.com  com         222     280
# 999990      999991   485319            eiretrip.com  com         222     280
#
#                     IDN_Domain IDN_TLD  PrevGlobalRank  PrevTldRank  \
# 999999  toyotamusicfactory.com     com          973201       471949
# 999998          soderhomes.com     com              -1           -1
# 999997           pinkwater.com     com              -1           -1
# 999996             mt-lock.com     com          952633       461429
# 999995              kireie.com     com              -1           -1
# 999994         keith-baker.com     com          973079       471891
# 999993          irishcycle.com     com          968062       469365
# 999992                hmag.com     com              -1           -1
# 999991    exploring-africa.com     com              -1           -1
# 999990            eiretrip.com     com              -1           -1
#
#         PrevRefSubNets  PrevRefIPs
# 999999             228         284
# 999998              -1          -1
# 999997              -1          -1
# 999996             232         284
# 999995              -1          -1
# 999994             228         287
# 999993             229         285
# 999992              -1          -1
# 999991              -1          -1
# 999990              -1          -1

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000000 entries, 0 to 999999
# Data columns (total 12 columns):
#  #   Column          Non-Null Count    Dtype
# ---  ------          --------------    -----
#  0   GlobalRank      1000000 non-null  int64
#  1   TldRank         1000000 non-null  int64
#  2   Domain          1000000 non-null  object
#  3   TLD             1000000 non-null  object
#  4   RefSubNets      1000000 non-null  int64
#  5   RefIPs          1000000 non-null  int64
#  6   IDN_Domain      1000000 non-null  object
#  7   IDN_TLD         1000000 non-null  object
#  8   PrevGlobalRank  1000000 non-null  int64
#  9   PrevTldRank     1000000 non-null  int64
#  10  PrevRefSubNets  1000000 non-null  int64
#  11  PrevRefIPs      1000000 non-null  int64
# dtypes: int64(8), object(4)
# memory usage: 91.6+ MB

# %%
path="/content/drive/MyDrive/data set/domains_location.csv"
df2=pd.read_csv(path)
df2.head(5)
# Out:
#   SourceCommonName location    Country
# 0       00221.info       SG    Senegal
# 1        01net.com       FR     France
# 2         01net.it       IT      Italy
# 3      0223.com.ar       AR  Argentina
# 4     022china.com       CH      China

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 37802 entries, 0 to 37801
# Data columns (total 3 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   SourceCommonName  37802 non-null  object
#  1   location          37802 non-null  object
#  2   Country           37801 non-null  object
# dtypes: object(3)
# memory usage: 886.1+ KB

# %%
highest_news_media_organisations = df2['Country'].value_counts().nlargest(10)
highest_news_media_organisations
# Out:
# Country
# United States     14111
# United Kingdom     1950
# Italy              1810
# France             1041
# Russia             1024
# Canada              887
# Germany             884
# China               780
# Turkey              725
# India               686
# Name: count, dtype: int64

# %%
df.describe()
# Out:
#           article_id
# count   58356.000000
# mean   298958.734492
# std    216023.477569
# min       418.000000
# 25%    121776.500000
# 50%    251651.000000
# 75%    451541.500000
# max    781308.000000
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_0['article_id'].plot(kind='hist', bins=20, title='article_id')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Categorical distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# _df_1.groupby('index').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_2['article_id'].plot(kind='line', figsize=(8, 4), title='article_id')
# plt.gca().spines[['top', 'right']].set_visible(False)
# <h4 class="colab-quickchart-section-title">Faceted distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# <string>:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
# from matplotlib import pyplot as plt
# import seaborn as sns
# figsize = (12, 1.2 * len(_df_3['index'].unique()))
# plt.figure(figsize=figsize)
# sns.violinplot(_df_3, x='article_id', y='index', inner='stick', palette='Dark2')
# sns.despine(top=True, right=True, bottom=True, left=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000000 entries, 0 to 999999
# Data columns (total 12 columns):
#  #   Column          Non-Null Count    Dtype
# ---  ------          --------------    -----
#  0   GlobalRank      1000000 non-null  int64
#  1   TldRank         1000000 non-null  int64
#  2   Domain          1000000 non-null  object
#  3   TLD             1000000 non-null  object
#  4   RefSubNets      1000000 non-null  int64
#  5   RefIPs          1000000 non-null  int64
#  6   IDN_Domain      1000000 non-null  object
#  7   IDN_TLD         1000000 non-null  object
#  8   PrevGlobalRank  1000000 non-null  int64
#  9   PrevTldRank     1000000 non-null  int64
#  10  PrevRefSubNets  1000000 non-null  int64
#  11  PrevRefIPs      1000000 non-null  int64
# dtypes: int64(8), object(4)
# memory usage: 91.6+ MB

# %%
largest_websites = df['source_name'].value_counts()
largest_websites
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3652         try:
# -> 3653             return self._engine.get_loc(casted_key)
#    3654         except KeyError as err:
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'source_name'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-18-17e00367db20> in <cell line: 1>()
# ----> 1 largest_websites = df['source_name'].value_counts()
#       2 largest_websites
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in __getitem__(self, key)
#    3759             if self.columns.nlevels > 1:
#    3760                 return self._getitem_multilevel(key)
# -> 3761             indexer = self.columns.get_loc(key)
#    3762             if is_integer(indexer):
#    3763                 indexer = [indexer]
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3653             return self._engine.get_loc(casted_key)
#    3654         except KeyError as err:
# -> 3655             raise KeyError(key) from err
#    3656         except TypeError:
#    3657             # If we have a listlike key, _check_indexing_error will raise
#
# KeyError: 'source_name'
